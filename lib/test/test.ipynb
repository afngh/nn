# %%
import sys
import os
sys.path.append(os.path.abspath('../..'))

# %%
from lib.activation import *
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.array(list(range(-5,6)))
ndata = np.array([relu(x) for x in data])

plt.plot(data,ndata)
plt.show()
